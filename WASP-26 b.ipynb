# %%
from fitransit.base import fitlpf
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Set model

# %%
wasp26b = fitlpf("WASP-26 b")

# %% [markdown]
# # 2. Get parameter

# %%
wasp26b.get_parameter()
# Out:
# WASP-26 b Properties
# Stellar Mass 		1.120000 		M_sun
# Planet Mass 		1.017460 		M_Jupiter
# Planet Orbital Period 	2.756600 		d
# Transit Time 		55123.637900 		MJD
# Planet Mass Reference: Calculated from MSINI and I

# %% [markdown]
# # 3. Download data

# %%
wasp26b.download_data()
# Out:
# obs_collection project                        obs_id
# -------------- ------- ----------------------------------------------------
#           TESS    TESS tess2020238165205-s0029-0000000032487566-0193-a_fast
#           TESS    TESS      tess2020238165205-s0029-0000000032487566-0193-s
#                        productFilename
# -------------------------------------------------------------
# tess2020239173514-s0029-s0029-0000000032487566-00382_dvt.fits
#       tess2020238165205-s0029-0000000032487566-0193-s_lc.fits
# ...
#
# finished!

# %% [markdown]
# # 4. Differential evolution

# %%
wasp26b.de(datadir = './data/WASP-26b/mastDownload/TESS/tess2020238165205-s0029-0000000032487566-0193-s/')
# Out:
# Global optimisation:   0%|          | 0/200 [00:00<?, ?it/s]

# %% [markdown]
# # 5. Single fit

# %%
wasp26b.fit_singles()
# Out:
# ...
# Run 4/4:   0%|          | 0/2500 [00:00<?, ?it/s]

# %%
for i in range(len(wasp26b.lpf.times)):
    fig = wasp26b.singles[i].plot_single_transit(ylim=(0.97,1.02))

# %%
fig = wasp26b.plot_ttv(plot_zero_epoch=True)

# %%
fig = wasp26b.plot_ttv_re()

# %%
wasp26b.prop
# Out:
# [{'canonical_name': 'WASP-44 b',
#   'exoplanetID': 5196,
#   'catalog_name': 'exoplanets.org',
#   'planet_name': 'WASP-44 b',
#   'disposition': 'confirmed planet',
#   'modified_date': '2022-03-28 23:48:18.396000',
#   'star_name': 'WASP-44',
#   'component': 'b',
#   'Rs': 0.927,
#   'Rs_unit': 'R_sun',
#   'Rs_upper': 0.068,
#   'Rs_lower': 0.057,
#   'Rs_ref': 'Anderson 2012',
#   'Rs_url': 'http://adsabs.harvard.edu/abs/2012MNRAS.422.1988A',
#   'Ms': 0.951,
#   'Ms_unit': 'M_sun',
#   'Ms_upper': 0.034,
#   'Ms_lower': 0.034,
#   'Ms_ref': 'Anderson 2012',
#   'Ms_url': 'http://adsabs.harvard.edu/abs/2012MNRAS.422.1988A',
#   'Fe/H': 0.06,
#   'Fe/H_upper': 0.1,
#   'Fe/H_lower': 0.1,
#   'Fe/H_ref': 'Anderson 2012',
#   'Fe/H_url': 'http://adsabs.harvard.edu/abs/2012MNRAS.422.1988A',
#   'stellar_gravity': 4.481,
#   'stellar_gravity_upper': 0.068,
#   'stellar_gravity_lower': 0.057,
#   'stellar_gravity_ref': 'Anderson 2012',
# ...
