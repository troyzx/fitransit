# %%
import fitransit

# %%
fitransit.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/troy/worktable/fitransit/test.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B65.108.42.25/home/troy/worktable/fitransit/test.ipynb#ch0000001vscode-remote?line=0'>1</a> fitransit.SingleFit()
#
# AttributeError: module 'fitransit' has no attribute 'SingleFit'
