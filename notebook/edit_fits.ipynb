# %%
from astropy.io import fits
import astropy

# %%
hdul_old = fits.open('./data/WASP-71b/mastDownload/TESS/tess2018292075959-s0004-0000000422655579-0124-s_lc.fits')
hdul = fits.open('./data/WASP-71b/mastDownload/TESS/tess2018292075959-s0004-0000000422655579-0124-s/tess2018292075959-s0004-0000000422655579-0124-s_lc.fits')

# %%
hdul_old[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standards
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T / file contains extensions
# NEXTEND =                    2 / number of standard extensions
# EXTNAME = 'PRIMARY '           / name of extension
# EXTVER  =                    1 / extension version number (not format version)
# SIMDATA =                    F / file is based on simulated data
# ORIGIN  = 'NASA/Ames'          / institution responsible for creating this file
# DATE    = '2020-12-02'         / file creation date.
# TSTART  =    1410.906219939742 / observation start time in BTJD
# TSTOP   =    1436.839006338450 / observation stop time in BTJD
# DATE-OBS= '2018-10-19T09:43:48.219' / TSTART as UTC calendar date
# DATE-END= '2018-11-14T08:07:00.964' / TSTOP as UTC calendar date
# CREATOR = '32261 LightCurveExporterPipelineModule' / pipeline job and program us
# ...

# %%
hdul[0].header = hdul_old[0].header
hdul.writeto('data/WASP-71b/mastDownload/TESS/tess2018292075959-s0004-0000000422655579-0124-s/tess2018292075959-s0004-0000000422655579-0124-s_lc.fits',overwrite=True)

# %%
hdul.close()
hdul_old.close()
