# %%
import pandas as pd
from astropy.table import Table

# %%
table = Table.read('data/WASP-18b/mastDownload/TESS/tess2018234235059-s0002-0000000100100827-0121-s/tess2018234235059-s0002-0000000100100827-0121-s_lc.fits',hdu=1)
df = table.to_pandas()  
df
# Out:
#               TIME  TIMECORR  CADENCENO      SAP_FLUX  SAP_FLUX_ERR  \
# 0      1354.105952  0.003284      91186           NaN           NaN
# 1      1354.107340  0.003284      91187           NaN           NaN
# 2      1354.108729  0.003284      91188           NaN           NaN
# 3      1354.110118  0.003284      91189           NaN           NaN
# 4      1354.111507  0.003285      91190  45699.730469     24.585836
# ...            ...       ...        ...           ...           ...
# 19732  1381.511903  0.003691     110918  45848.359375     25.017271
# 19733  1381.513292  0.003691     110919  45941.605469     25.034466
# 19734  1381.514681  0.003691     110920  45924.988281     25.024431
# 19735  1381.516070  0.003691     110921  45928.765625     25.021816
# 19736  1381.517459  0.003691     110922  45919.125000     25.025965
#
#            SAP_BKG  SAP_BKG_ERR   PDCSAP_FLUX  PDCSAP_FLUX_ERR  QUALITY  \
# 0              NaN          NaN           NaN              NaN      168
# ...

# %%
df.to_csv('WASP-18b.txt', sep='\t', columns=['TIME','SAP_FLUX'], index=False)
