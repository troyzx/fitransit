# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('priors.csv',skipinitialspace=True).values
# Out:
# array([['P', 'gaussian', 6.0, 0.001, nan],
#        ['t0', 'gaussian', 2457843.45246, 0.007, nan],
#        ['a', 'gaussian', 7.64, 0.5, nan],
#        ['inc', 'gaussian', 88.5, 1.2, nan],
#        ['rp', 'fixed', 0.13, nan, nan],
#        ['ecc', 'fixed', 0.0, nan, nan]], dtype=object)

# %%
from transitfit import run_retrieval

results = run_retrieval('input_data.csv', 'priors.csv')
# Out:
# Auto mode detect has set 'all' mode
# Priors:
# Limb darkening model: quadratic
# n telescopes: 1
# n filters: 1
# n epochs: 1
# P:	t -	f -	e -	Gaussian - mean: 6.0 - stdev:              0.001
# t0:	t -	f -	e -	Gaussian - mean: 2457843.45246 - stdev:  0.007
# a:	t -	f -	e -	Gaussian - mean: 7.64 - stdev:           0.5
# rp:	t -	f 0	e -	Fixed - value: 0.05
# inc:	t -	f -	e -	Gaussian - mean: 88.5 - stdev:           1.2
# ecc:	t -	f -	e -	Fixed - value: 0.0
# w:	t -	f -	e -	Fixed - value: 90
# q0:	t -	f 0	e -	Uniform - min: 0 - max: 1
# q1:	t -	f 0	e -	Uniform - min: 0 - max: 1
# norm:	t 0	f 0	e 0	Uniform - min: 7.963942627570656e-05 - max: 0.00025516796107093794
# d0_0:	t 0	f 0	e 0	Uniform - min: -10 - max: 10
# Total 8 fitting parameters
# Exception while calling prior_transform function:
#   params: [0.28181173 0.56170895 0.32049563 0.44162646 0.58874441 0.35578166
#  0.06736652 0.83039502]
#   args: []
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
# ...
