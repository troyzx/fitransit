# %%
import pandas as pd
from pytransit.lpf.transitlpf import TransitLPF

# %%
df = pd.read_csv('./data/wasp_4b_transit_times-Copy1.csv')

# %%
lpf = TransitLPF(name='WASP-4b',times=df.time,fluxes=df.flux)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/km/vcj2rw_13w18r4lpbsqkyqxm0000gn/T/ipykernel_56983/1976109336.py in <module>
# ----> 1 lpf = TransitLPF(name='WASP-4b',times=df.time,fluxes=df.flux)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'flux'
