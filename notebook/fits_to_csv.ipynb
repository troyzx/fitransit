# %%
from astropy.table import Table
import numpy as np
from matplotlib import pyplot as plt
import pytransit

# %%
table = Table.read('data/WASP-11b/MAST_2022-01-02T0720/TESS/tess2021232031932-s0042-0000000085593751-0213-s/tess2021232031932-s0042-0000000085593751-0213-s_lc.fits',hdu=1)
df_raw = table.to_pandas()  
df_raw
# Out:
#               TIME  TIMECORR  CADENCENO     SAP_FLUX  SAP_FLUX_ERR  \
# 0      2447.685981  0.000460     878566          NaN           NaN
# 1      2447.687370  0.000460     878567          NaN           NaN
# 2      2447.688759  0.000460     878568          NaN           NaN
# 3      2447.690148  0.000460     878569          NaN           NaN
# 4      2447.691537  0.000461     878570  6037.868164     10.223193
# ...            ...       ...        ...          ...           ...
# 18337  2473.156333  0.002768     896903          NaN           NaN
# 18338  2473.157722  0.002768     896904          NaN           NaN
# 18339  2473.159111  0.002769     896905          NaN           NaN
# 18340  2473.160500  0.002769     896906          NaN           NaN
# 18341  2473.161889  0.002769     896907          NaN           NaN
#
#            SAP_BKG  SAP_BKG_ERR  PDCSAP_FLUX  PDCSAP_FLUX_ERR  QUALITY  \
# 0              NaN          NaN          NaN              NaN      168
# ...

# %%
data = np.array(df_raw[['TIME','SAP_FLUX','SAP_FLUX_ERR']])

# %%
np.savetxt('./transitfit/data.csv', data, delimiter=',')
